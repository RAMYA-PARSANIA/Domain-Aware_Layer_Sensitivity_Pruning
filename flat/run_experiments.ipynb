# %%
# !pip install torch transformers datasets evaluate sentence-transformers scikit-learn numpy pandas matplotlib seaborn psutil tqdm joblib huggingface_hub accelerate
# Out:
# ...
#   Obtaining dependency information for accelerate from https://files.pythonhosted.org/packages/7e/46/02ac5e262d4af18054b3e922b2baedbb2a03289ee792162de60a865defc5/accelerate-1.13.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 7.7 MB/s eta 0:00:00:00:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade --force-reinstall transformers==4.44.2 accelerate==0.30.1
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cublas (/home/debopriya/report_gen/experiments_filter/NLP_Project/.venv/lib64/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~vidia-cublas (/home/debopriya/report_gen/experiments_filter/NLP_Project/.venv/lib64/python3.12/site-packages)
# ...
#   Obtaining dependency information for transformers==4.44.2 from https://files.pythonhosted.org/packages/75/35/07c9879163b603f0e464b0f6e6e628a2340cfc7cdc5ca8e7d52d776710d4/transformers-4.44.2-py3-none-any.whl.metadata
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# ...
#   Obtaining dependency information for accelerate==0.30.1 from https://files.pythonhosted.org/packages/e9/bb/1edd2c836071e91d2bd331b9542bbd592e23d1474645b9c6fd56232caace/accelerate-0.30.1-py3-none-any.whl.metadata
#   Using cached accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# ...

# %%
# !python 1.py
# Out:
# Loading microsoft/Phi-3.5-mini-instruct for Multi-Domain Profiling...
# config.json: 3.45kB [00:00, 14.8MB/s]
# configuration_phi3.py: 11.2kB [00:00, 50.8MB/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py: 73.8kB [00:00, 29.4MB/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# ...

# %%
# !python 2.py
# Out:
# ...
# Pruning 'general' Subnetwork (20.0% of MLP)
# ...
# Loading Original Unpruned Model...
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:03<00:00,  1.78s/it]
# Executing Subnetwork Surgery & Zero-Shot Bias Compensation...
# Saving 'general' subnetwork to ./phi-3.5-pruned-20_general...
# Fetching 3 files:  33%|█████████                  | 1/3 [00:00<00:00,  2.67it/s]
# sample_finetune.py: 6.13kB [00:00, 26.2MB/s]
# Fetching 3 files: 100%|███████████████████████████| 3/3 [00:06<00:00,  2.06s/it]
# Finished general!
#
#
# ...
# Pruning 'math' Subnetwork (20.0% of MLP)
# ...
# Loading Original Unpruned Model...
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# ...

# %%
# !python 3.py
# Out:
# Fetching 20 evaluation samples from each task...
# README.md: 26.7kB [00:00, 86.4MB/s]
# ...
# Resolving data files: 100%|██████████████████| 26/26 [00:00<00:00, 46424.82it/s]
# README.md: 15.6kB [00:00, 353kB/s]
# README.md: 35.3kB [00:00, 109MB/s]
#
# [EVALUATING] MICROSOFT/PHI-3.5-MINI-INSTRUCT...
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:02<00:00,  1.38s/it]
#  > Task: Exact_Match (TriviaQA)
#   0%|                                                    | 0/20 [00:00<?, ?it/s]The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# ...
