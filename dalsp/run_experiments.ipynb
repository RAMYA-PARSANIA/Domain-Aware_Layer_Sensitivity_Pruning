# %%
# !pip install torch transformers datasets evaluate sentence-transformers scikit-learn numpy pandas matplotlib seaborn psutil tqdm joblib huggingface_hub accelerate rouge_score

# %%
# !pip install --upgrade --force-reinstall transformers==4.44.2 accelerate==0.30.1
# Out:
# ...
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached packaging-26.1-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# ...
#   Using cached regex-2026.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# ...

# %%
# !pip install packaging ninja
# !pip install flash-attn --no-build-isolation
# Out:
# ...
#   Using cached flash_attn-2.8.3.tar.gz (8.4 MB)
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached einops-0.8.2-py3-none-any.whl (65 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for flash-attn (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1119 lines of output]
#       /home/debopriya/report_gen/experiments_filter/NLP_Project/venv312/lib64/python3.12/site-packages/setuptools/_vendor/wheel/bdist_wheel.py:4: FutureWarning: The 'wheel' package is no longer the canonical location of the 'bdist_wheel' command, and will be removed in a future release. Please update to setuptools v70.1 or later which contains an integrated version of this command.
#         warn(
#
#
#       torch.__version__  = 2.11.0+cu130
#
#
# ...

# %%
# !python Step1_Profile_Domains.py
# Out:
# Loading microsoft/Phi-3.5-mini-instruct for Multi-Domain Profiling (DALSP)...
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:02<00:00,  1.31s/it]
#
#
# ...
# Profiling Domain: GENERAL
# ...
#   Streaming 'wikitext' ...
# ...
#   Calibrating [general]: 100%|██████████████████| 32/32 [00:04<00:00,  7.21it/s]
#   Computing Wanda scores + layer entropy for 'general' ...
#
#   Layer entropy summary (nats)  [high=sensitive, low=prunable]:
#     Layer 00: 9.0109  ██████████████████████████████
#     Layer 01: 9.0108  █████████████████████████████
#     Layer 02: 0.0000
#     Layer 03: 9.0109  █████████████████████████████
#     Layer 04: 0.0000
#     Layer 05: 9.0108  █████████████████████████████
#     Layer 06: 9.0106  █████████████████████████████
# ...

# %%
# !python Step2_Prune_Subnetworks.py
# Out:
# ...
# DALSP Pruning  ·  Domain: GENERAL  ·  Budget: 20% avg
# ...
# Loading original unpruned model...
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:02<00:00,  1.27s/it]
#
# DALSP allocation summary (average = 20.33%):
#   Layer |  Entropy | PruneRate | Allocation bar
#   ------+----------+------------+-------------------------------
#       0 |   9.0109 |    25.63% | ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓ ← aggressive
#       1 |   9.0108 |    25.63% | ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓ ← aggressive
#       2 |   0.0000 |    10.00% | ▓▓▓▓▓▓▓ ← conservative
#       3 |   9.0109 |    25.63% | ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓ ← aggressive
#       4 |   0.0000 |    10.00% | ▓▓▓▓▓▓▓ ← conservative
#       5 |   9.0108 |    25.63% | ▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓ ← aggressive
# ...

# %%
# !python Step3_Evaluate_All.py
# Out:
# Fetching 100 evaluation samples per task ...
# ...
# Resolving data files: 100%|██████████████████| 26/26 [00:00<00:00, 40240.55it/s]
#   Loaded 6 tasks.
#
#
# [EVAL] microsoft/Phi-3.5-mini-instruct
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:02<00:00,  1.17s/it]
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# WARNING:transformers_modules.microsoft.Phi-3.5-mini-instruct.2fe192450127e6a83f7441aef6e3ca586c338b77.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
#   > Exact_Match (TriviaQA) (100 samples, max_tokens=64)
#   > Summarization (CNN/DM) (100 samples, max_tokens=128)
#   > Logic (GSM8K) (100 samples, max_tokens=256)
# ...
